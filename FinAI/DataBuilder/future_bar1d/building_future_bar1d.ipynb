# %%
import sys
path = '/Users/xiehao/Desktop/workspace/X2AI/FinAI/'
if path not in sys.path:
    sys.path.append(path)

from datetime import datetime, timedelta
from DataBuilder.future_bar1d.builder import FutureBar1dBuilder

# today = datetime.strptime("2025-06-10", "%Y-%m-%d")
today = datetime.now()
start_date = (today - timedelta(days=30)).strftime("%Y-%m-%d")
end_date = today.strftime("%Y-%m-%d")

now = datetime.now()
FutureBar1dBuilder(
    start_date=start_date,
    end_date=end_date
).build()
print(f"爬取行情数据, 耗时: {datetime.now() - now}")
# Out:
# 爬取舆情数据, 耗时: 0:00:00.877927
