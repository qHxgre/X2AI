# %%
import sys
path = '/Users/xiehao/Desktop/workspace/X2AI/FinAI/'
if path not in sys.path:
    sys.path.append(path)

# from robot import SentimentalBot
import pandas as pd


# for today in pd.date_range(start="2025-06-10", end="2025-06-10", freq='D'):
#     print(today)
#     bot = SentimentalBot(
#         start_date=today,
#         end_date=today,
#         llms='deepseek',
#         using_cache=True,
#     )
#     data = bot.get_articles()
#     if len(data) == 0:
#         continue
#     data = pd.DataFrame(data)
#     data = data[data["sub_category"].isin(["最新资讯", "日报", "热点研究", "周报"])].to_dict(orient='records')
#     assistant_reports = bot.assistant(data, run_parallel=True)

# %%
from robot import SentimentalResearcherBot

today = "2025-06-10"

bot = SentimentalResearcherBot(
    start_date=today,
    end_date=today,
    llms='deepseek',
    using_cache=True,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from robot import SentimentalResearcherBot
#       3 today = "2025-06-10"
#       5 bot = SentimentalResearcherBot(
#       6     start_date=today,
#       7     end_date=today,
#       8     llms='deepseek',
#       9     using_cache=True,
#      10 )
#
# File ~/Desktop/workspace/X2AI/FinAI/AIBots/SentimentalBot/robot.py:13
#       9 from AIBots.SentimentalBot.templets import TEMPLET_ARTICLE
#      10 from AIBots.SentimentalBot.schema import SugarSentimentalAssistantSchema
# ---> 13 class SentimentalResearcherBot(BaseAI, BaseBuilder):
#      14     """舆情AI研究员"""
#      15     datasource_id = "ai_sugar_sentimental_researcher"
#
# File ~/Desktop/workspace/X2AI/FinAI/AIBots/SentimentalBot/robot.py:98, in SentimentalResearcherBot()
#      94     data["date"] = data["date"].dt.strftime("%Y-%m-%d")
# ...
