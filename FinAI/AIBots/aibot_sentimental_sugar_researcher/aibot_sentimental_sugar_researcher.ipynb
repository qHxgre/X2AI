# %%
import sys
path = '/Users/xiehao/Desktop/workspace/X2AI/FinAI/'
if path not in sys.path:
    sys.path.append(path)

import pandas as pd
from robot import AIBotSentimentalSugarResearcher


for today in pd.date_range(start="2025-04-01", end="2025-07-01", freq='D'):
    bot = AIBotSentimentalSugarResearcher(
        start_date=today.strftime('%Y-%m-%d'),
        end_date=today.strftime('%Y-%m-%d'),
        llms='deepseek',
        cache=True,
    )

    bot.analyzing()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 18
#      10 for today in pd.date_range(start="2025-04-01", end="2025-07-01", freq='D'):
#      11     bot = AIBotSentimentalSugarResearcher(
#      12         start_date=today,
#      13         end_date=today,
#      14         llms='deepseek',
#      15         cache=True,
#      16     )
# ---> 18     bot.analyzing()
#
# File ~/Desktop/workspace/X2AI/FinAI/AIBots/aibot_sentimental_sugar_researcher/robot.py:206, in AIBotSentimentalSugarResearcher.analyzing(self, run_parallel)
#     204 # STEP 4: AI分析
#     205 if run_parallel:
# --> 206     reports = self.parallel_analyzing(articles)
#     207 else:
#     208     reports = self.serial_analyzing(articles)
#
# ...
