# %%
import time
import random
from wechatCrawler import wechatCrawler

mapping = {
    '【中信建投】多智能体投资决策框架': 'https://mp.weixin.qq.com/s/lBx93a1T4KFExcIt-UtddA',
    '【中信建投】“逐鹿”Alpha专题报告（二十）——基于数亿新闻上下文的本地RAG系统用于市场择时及行业轮动': 'https://mp.weixin.qq.com/s/3TxqVj-fbQ0LqXp3UMHJ4Q',
    '【中信建投】“逐鹿”Alpha专题报告（二十三）——融合LLMs进化的基本面因子挖掘统一框架': 'https://mp.weixin.qq.com/s/TG5KbfqcKac5KRyaByB2Yw',
    '【中信建投】“逐鹿”Alpha 专题报告（二十二）——Factor Zoo II 基本面因子挖掘统一框架': 'https://mp.weixin.qq.com/s/yuu7TeRFHiAm3eqDhUjLTw',
    '【中信建投】“逐鹿”Alpha 专题报告（二十一）——基于新闻、研报、财务、技术指标的大模型个股分析框架初探': 'https://mp.weixin.qq.com/s/tXe5EIFT12CE1TBGENQhGw',
    '【中信建投】“逐鹿”Alpha专题报告（二十五）——DeepSeek+RAG行业轮动策略': 'https://mp.weixin.qq.com/s/GQFKqJwKOUADgCbqUsJm3Q',
}

async def main(url, filename):
    async with wechatCrawler("./AI2Investing") as crawler:
        await crawler.url_to_pdf(url, filename)

for filename, url in mapping.items():
    await main(url, filename)
    time.sleep(random.uniform(1, 5))
# Out:
# Saved 【中信建投】多智能体投资决策框架.pdf to /Users/xiehao/Desktop/workspace/AI2Investing/【中信建投】多智能体投资决策框架.pdf
# Saved 【中信建投】“逐鹿”Alpha专题报告（二十）——基于数亿新闻上下文的本地RAG系统用于市场择时及行业轮动.pdf to /Users/xiehao/Desktop/workspace/AI2Investing/【中信建投】“逐鹿”Alpha专题报告（二十）——基于数亿新闻上下文的本地RAG系统用于市场择时及行业轮动.pdf
# Saved 【中信建投】“逐鹿”Alpha专题报告（二十三）——融合LLMs进化的基本面因子挖掘统一框架.pdf to /Users/xiehao/Desktop/workspace/AI2Investing/【中信建投】“逐鹿”Alpha专题报告（二十三）——融合LLMs进化的基本面因子挖掘统一框架.pdf
# Saved 【中信建投】“逐鹿”Alpha 专题报告（二十二）——Factor Zoo II 基本面因子挖掘统一框架.pdf to /Users/xiehao/Desktop/workspace/AI2Investing/【中信建投】“逐鹿”Alpha 专题报告（二十二）——Factor Zoo II 基本面因子挖掘统一框架.pdf
# Saved 【中信建投】“逐鹿”Alpha 专题报告（二十一）——基于新闻、研报、财务、技术指标的大模型个股分析框架初探.pdf to /Users/xiehao/Desktop/workspace/AI2Investing/【中信建投】“逐鹿”Alpha 专题报告（二十一）——基于新闻、研报、财务、技术指标的大模型个股分析框架初探.pdf
# Saved 【中信建投】“逐鹿”Alpha专题报告（二十五）——DeepSeek+RAG行业轮动策略.pdf to /Users/xiehao/Desktop/workspace/AI2Investing/【中信建投】“逐鹿”Alpha专题报告（二十五）——DeepSeek+RAG行业轮动策略.pdf
