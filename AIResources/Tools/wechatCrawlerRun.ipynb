# %%
import time
import random
from wechatCrawler import wechatCrawler

mapping = {
    # '【中信建投】多智能体投资决策框架': 'https://mp.weixin.qq.com/s/lBx93a1T4KFExcIt-UtddA',
    # '【中信建投】“逐鹿”Alpha专题报告（二十）——基于数亿新闻上下文的本地RAG系统用于市场择时及行业轮动': 'https://mp.weixin.qq.com/s/3TxqVj-fbQ0LqXp3UMHJ4Q',
    # '【中信建投】“逐鹿”Alpha专题报告（二十三）——融合LLMs进化的基本面因子挖掘统一框架': 'https://mp.weixin.qq.com/s/TG5KbfqcKac5KRyaByB2Yw',
    # '【中信建投】“逐鹿”Alpha 专题报告（二十二）——Factor Zoo II 基本面因子挖掘统一框架': 'https://mp.weixin.qq.com/s/yuu7TeRFHiAm3eqDhUjLTw',
    # '【中信建投】“逐鹿”Alpha 专题报告（二十一）——基于新闻、研报、财务、技术指标的大模型个股分析框架初探': 'https://mp.weixin.qq.com/s/tXe5EIFT12CE1TBGENQhGw',
    # '【中信建投】“逐鹿”Alpha专题报告（二十五）——DeepSeek+RAG行业轮动策略': 'https://mp.weixin.qq.com/s/GQFKqJwKOUADgCbqUsJm3Q',
    # '【方正证券】扣子空间+MCP服务在金融投研工作中的应用探讨——DeepSeek应用系列研究之四': 'https://mp.weixin.qq.com/s/ZRTycwRNYTKdLp8FZhb3eQ',
    # '【方正证券】Manus在金融投研工作中的应用测评——DeepSeek应用系列研究之三': 'https://mp.weixin.qq.com/s/UVWynkwZg9LsP7t0PyQ_3w',
    # '【方正证券】DeepSeek知识库管理与AI Agent应用探索——DeepSeek应用系列研究之二': 'https://mp.weixin.qq.com/s/sZP6Wl8EDadMP8q7bud_dw',
    # '【方正证券】DeepSeek在投资研究工作中的应用初探——DeepSeek应用系列研究之一': 'https://mp.weixin.qq.com/s/o3yvJsd7KMjfNVGeiVXrVQ',
    # '【民生证券】解码管理层论述：AI 驱动的年报 MD&A 分析与选股 ': 'https://mp.weixin.qq.com/s/0ODrHQPGIlmVcGn4GoHFOw',
    # '【民生证券】研报+公告+调研+量价全数据智能投研AI构建': 'https://mp.weixin.qq.com/s/eZgtZs9hGmbl87d8oDOwlw',
    # '【民生证券】如何利用AI模型寻找日内最佳买卖点？': 'https://mp.weixin.qq.com/s/kbRQ3Q_2IE1NYLS5OJWBBg',
    # '【广发证券】机器学习选股训练手册': 'https://mp.weixin.qq.com/s/lVRlV7Qlu4NRgUdmNzrFEw',
    # '【广发证券】DeepSeek定量解析基金季报行业观点及行业轮动策略构建': 'https://mp.weixin.qq.com/s/9SYsaHTE1lh6gb7dKatB2w',
    # '【广发证券】从知识库到知识图谱：DeepSeek&GraphRAG': 'https://mp.weixin.qq.com/s/YEbVTTW_pk_ulS0mtp0Wwg',
    # '【广发证券】如何使用DeepSeek提高投研效率': 'https://mp.weixin.qq.com/s/T7FWa99dEi4zzUg7f-NcOw',
}

async def main(url, filename):
    async with wechatCrawler("./AI2Investing") as crawler:
        await crawler.url_to_pdf(url, filename)

for filename, url in mapping.items():
    await main(url, filename)
    time.sleep(random.uniform(1, 5))
